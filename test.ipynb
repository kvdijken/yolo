# %%
import numpy as np
from math import floor

# %%
x = 0.27
log = int(np.log10(x))
# fd = (x // 10) ** log

# %%
log
# Out:
# 0

# %%
r = 5
r * 10 ** log
# Out:
# 5

# %%
int(-0.09)
# Out:
# 0

# %%
int(-1.1)
# Out:
# -1

# %%
x = 0.21
log = floor(np.log10(x))
log
# Out:
# -1

# %%
int(.21 / (10 ** (log-0)))
# Out:
# 2

# %%
def fd(x):
    log = floor(np.log10(x))
    return int(x / (10 ** log))

for x in np.linspace(0.01,6.3,200):
    print(x,fd(x))
# Out:
# 0.01 1
# 0.041608040201005024 4
# 0.07321608040201004 7
# 0.10482412060301506 1
# 0.1364321608040201 1
# 0.16804020100502512 1
# 0.19964824120603014 1
# 0.23125628140703516 2
# 0.2628643216080402 2
# 0.29447236180904524 2
# 0.32608040201005023 3
# 0.3576884422110552 3
# 0.3892964824120603 3
# 0.4209045226130653 4
# 0.4525125628140703 4
# 0.4841206030150753 4
# 0.5157286432160804 5
# 0.5473366834170854 5
# 0.5789447236180905 5
# 0.6105527638190954 6
# 0.6421608040201005 6
# 0.6737688442211055 6
# 0.7053768844221104 7
# 0.7369849246231155 7
# 0.7685929648241205 7
# 0.8002010050251256 8
# 0.8318090452261306 8
# 0.8634170854271356 8
# 0.8950251256281406 8
# 0.9266331658291457 9
# 0.9582412060301506 9
# 0.9898492462311557 9
# 1.0214572864321607 1
# 1.0530653266331658 1
# 1.0846733668341708 1
# 1.1162814070351759 1
# 1.147889447236181 1
# 1.1794974874371857 1
# 1.2111055276381908 1
# 1.2427135678391958 1
# 1.274321608040201 1
# 1.305929648241206 1
# 1.337537688442211 1
# ...

# %%
0 ** -1
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 0 ** -1
#
# ZeroDivisionError: 0.0 cannot be raised to a negative power

# %%
floor(np.log10(2))
# Out:
# 0
